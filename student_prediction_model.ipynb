# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Anudip\OneDrive\Desktop\minor project\Student_Performance.csv")

# %%
df.head(5)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail(5)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.size
# Out:
# 60000

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.sample(5)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 216               9               42                         No            8
# 7720              5               87                        Yes            6
# 7364              8               70                        Yes            8
# 6561              9               68                         No            8
# 8322              7               65                         No            7
#
#       Sample Question Papers Practiced  Performance Index
# 216                                  6               41.0
# 7720                                 3               71.0
# 7364                                 1               64.0
# 6561                                 2               70.0
# 8322                                 7               59.0

# %%
df.T
# Out:
#                                   0     1     2     3     4     5     6     \
# Hours Studied                        7     4     8     5     7     3     7
# Previous Scores                     99    82    51    52    75    78    73
# Extracurricular Activities         Yes    No   Yes   Yes    No    No   Yes
# Sleep Hours                          9     4     7     5     8     9     5
# Sample Question Papers Practiced     1     2     2     2     5     6     6
# Performance Index                 91.0  65.0  45.0  36.0  66.0  61.0  63.0
#
#                                   7     8     9     ...  9990  9991  9992  \
# Hours Studied                        8     5     4  ...     9     5     9
# Previous Scores                     45    77    89  ...    43    97    52
# Extracurricular Activities         Yes    No    No  ...    No   Yes    No
# Sleep Hours                          4     8     4  ...     7     7     9
# Sample Question Papers Practiced     6     2     0  ...     4     4     7
# Performance Index                 42.0  61.0  69.0  ...  40.0  83.0  50.0
#
#                                   9993  9994  9995  9996  9997  9998  9999
# Hours Studied                        9     6     1     7     6     9     7
# Previous Scores                     58    46    49    64    83    97    74
# Extracurricular Activities         Yes   Yes   Yes   Yes   Yes   Yes    No
# Sleep Hours                          7     8     4     8     8     7     8
# Sample Question Papers Practiced     7     0     2     5     5     0     1
# Performance Index                 55.0  39.0  23.0  58.0  74.0  95.0  64.0
#
# [6 rows x 10000 columns]

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df['Performance Index'].unique()
# Out:
# array([ 91.,  65.,  45.,  36.,  66.,  61.,  63.,  42.,  69.,  84.,  73.,
#         27.,  33.,  68.,  43.,  67.,  70.,  30.,  71.,  85.,  57.,  35.,
#         49.,  83.,  74.,  39.,  58.,  47.,  60.,  32.,  64.,  54.,  17.,
#         53.,  75.,  52.,  78.,  38.,  98.,  87.,  41.,  81.,  15.,  88.,
#         95.,  29.,  21.,  76.,  25.,  34.,  50.,  56.,  82.,  23.,  46.,
#         92.,  77.,  86.,  44.,  94.,  40., 100.,  31.,  26.,  18.,  51.,
#         72.,  16.,  28.,  89.,  48.,  37.,  62.,  59.,  19.,  79.,  22.,
#         10.,  90.,  80.,  24.,  20.,  96.,  55.,  97.,  12.,  93.,  14.,
#         99.,  11.,  13.])

# %%
df['Performance Index'].value_counts()
# Out:
# Performance Index
# 67.0     187
# 45.0     185
# 49.0     181
# 56.0     181
# 40.0     180
#         ...
# 14.0       7
# 99.0       6
# 11.0       5
# 100.0      3
# 10.0       1
# Name: count, Length: 91, dtype: int64

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Extracurricular Activities'] = df['Extracurricular Activities'].map({'Yes': 1, 'No': 0})

# %%
df.corr()
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# Performance Index                                   0.024525     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Extracurricular Activities                                0.013103
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# Hours Studied                              0.373730
# Previous Scores                            0.915189
# Extracurricular Activities                 0.024525
# Sleep Hours                                0.048106
# Sample Question Papers Practiced           0.043268
# Performance Index                          1.000000

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_db273_row0_col0, #T_db273_row1_col1, #T_db273_row2_col2, #T_db273_row3_col3, #T_db273_row4_col4, #T_db273_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_db273_row0_col1, #T_db273_row1_col0, #T_db273_row2_col3, #T_db273_row2_col5, #T_db273_row3_col2, #T_db273_row3_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_db273_row0_col2, #T_db273_row0_col3, #T_db273_row3_col5, #T_db273_row4_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_db273_row0_col4, #T_db273_row2_col0, #T_db273_row3_col0, #T_db273_row3_col1, #T_db273_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_db273_row0_col5 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_db273_row1_col2, #T_db273_row1_col3, #T_db273_row4_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_db273_row1_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_db273_row1_col5 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_db273_row2_col1, #T_db273_row4_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_db273_row2_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_db273_row4_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_db273_row5_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_db273_row5_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_db273_row5_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_db273_row5_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_db273_row5_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# </style>
# <table id="T_db273">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db273_level0_col0" class="col_heading level0 col0" >Hours Studied</th>
#       <th id="T_db273_level0_col1" class="col_heading level0 col1" >Previous Scores</th>
#       <th id="T_db273_level0_col2" class="col_heading level0 col2" >Extracurricular Activities</th>
#       <th id="T_db273_level0_col3" class="col_heading level0 col3" >Sleep Hours</th>
#       <th id="T_db273_level0_col4" class="col_heading level0 col4" >Sample Question Papers Practiced</th>
#       <th id="T_db273_level0_col5" class="col_heading level0 col5" >Performance Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db273_level0_row0" class="row_heading level0 row0" >Hours Studied</th>
#       <td id="T_db273_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_db273_row0_col1" class="data row0 col1" >-0.012390</td>
#       <td id="T_db273_row0_col2" class="data row0 col2" >0.003873</td>
#       <td id="T_db273_row0_col3" class="data row0 col3" >0.001245</td>
#       <td id="T_db273_row0_col4" class="data row0 col4" >0.017463</td>
#       <td id="T_db273_row0_col5" class="data row0 col5" >0.373730</td>
#     </tr>
#     <tr>
#       <th id="T_db273_level0_row1" class="row_heading level0 row1" >Previous Scores</th>
#       <td id="T_db273_row1_col0" class="data row1 col0" >-0.012390</td>
#       <td id="T_db273_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_db273_row1_col2" class="data row1 col2" >0.008369</td>
#       <td id="T_db273_row1_col3" class="data row1 col3" >0.005944</td>
#       <td id="T_db273_row1_col4" class="data row1 col4" >0.007888</td>
#       <td id="T_db273_row1_col5" class="data row1 col5" >0.915189</td>
#     </tr>
#     <tr>
#       <th id="T_db273_level0_row2" class="row_heading level0 row2" >Extracurricular Activities</th>
#       <td id="T_db273_row2_col0" class="data row2 col0" >0.003873</td>
#       <td id="T_db273_row2_col1" class="data row2 col1" >0.008369</td>
#       <td id="T_db273_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_db273_row2_col3" class="data row2 col3" >-0.023284</td>
#       <td id="T_db273_row2_col4" class="data row2 col4" >0.013103</td>
#       <td id="T_db273_row2_col5" class="data row2 col5" >0.024525</td>
#     </tr>
#     <tr>
#       <th id="T_db273_level0_row3" class="row_heading level0 row3" >Sleep Hours</th>
#       <td id="T_db273_row3_col0" class="data row3 col0" >0.001245</td>
#       <td id="T_db273_row3_col1" class="data row3 col1" >0.005944</td>
#       <td id="T_db273_row3_col2" class="data row3 col2" >-0.023284</td>
#       <td id="T_db273_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_db273_row3_col4" class="data row3 col4" >0.003990</td>
#       <td id="T_db273_row3_col5" class="data row3 col5" >0.048106</td>
#     </tr>
#     <tr>
#       <th id="T_db273_level0_row4" class="row_heading level0 row4" >Sample Question Papers Practiced</th>
#       <td id="T_db273_row4_col0" class="data row4 col0" >0.017463</td>
#       <td id="T_db273_row4_col1" class="data row4 col1" >0.007888</td>
#       <td id="T_db273_row4_col2" class="data row4 col2" >0.013103</td>
#       <td id="T_db273_row4_col3" class="data row4 col3" >0.003990</td>
#       <td id="T_db273_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_db273_row4_col5" class="data row4 col5" >0.043268</td>
#     </tr>
#     <tr>
#       <th id="T_db273_level0_row5" class="row_heading level0 row5" >Performance Index</th>
#       <td id="T_db273_row5_col0" class="data row5 col0" >0.373730</td>
#       <td id="T_db273_row5_col1" class="data row5 col1" >0.915189</td>
#       <td id="T_db273_row5_col2" class="data row5 col2" >0.024525</td>
#       <td id="T_db273_row5_col3" class="data row5 col3" >0.048106</td>
#       <td id="T_db273_row5_col4" class="data row5 col4" >0.043268</td>
#       <td id="T_db273_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df.select_dtypes(include=['int64', 'float64']).corr(), annot=True , cmap='GnBu' , fmt='.1f' , linewidth=.6)
plt.title('Correlation heatmap for numerical features')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.distplot(df["Performance Index"])
# Out:
# <Axes: xlabel='Performance Index', ylabel='Density'>

# %%
sns.boxplot(data=df,y="Performance Index",x="Hours Studied")
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.boxplot(x="Extracurricular Activities", y="Performance Index", data=df)
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
sns.pointplot(data=df,x="Hours Studied",y="Performance Index")
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.catplot(data=df,x="Hours Studied",y="Performance Index")

# %%
sns.pairplot(df,x_vars=["Sample Question Papers Practiced","Sleep Hours","Hours Studied"],y_vars="Performance Index",kind="scatter")

# %% [markdown]
# MODEL TRAINING

# %%
x = df.drop('Performance Index', axis=1)
y = df['Performance Index']

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 5 columns]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)

# %%
lr.coef_
# Out:
# array([2.85248393, 1.0169882 , 0.60861668, 0.47694148, 0.19183144])

# %%
lr.intercept_
# Out:
# np.float64(-33.921946215556126)

# %%
ypred
# Out:
# array([54.71185392, 22.61551294, 47.90314471, ..., 16.79341955,
#        63.34327368, 45.94262301])

# %%
plt.scatter(ytest,ypred)

# %%
sns.distplot(ytest-ypred)
# Out:
# <Axes: xlabel='Performance Index', ylabel='Density'>

# %%
pd.DataFrame(lr.coef_,index=x.columns,columns=["coefficients"])
# Out:
#                                   coefficients
# Hours Studied                         2.852484
# Previous Scores                       1.016988
# Extracurricular Activities            0.608617
# Sleep Hours                           0.476941
# Sample Question Papers Practiced      0.191831

# %%
print(f"Actual: {ytest[:5]}")
print(f"Predicted: {ypred[:5]}")
# Out:
# Actual: 6252    51.0
# 4684    20.0
# 1731    46.0
# 4742    28.0
# 4521    41.0
# Name: Performance Index, dtype: float64
# Predicted: [54.71185392 22.61551294 47.90314471 31.28976748 43.00457042]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(ytest, ypred, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', linewidth=2)
plt.xlabel('Actual Performance Index')
plt.ylabel('Predicted Performance Index')
plt.title('Actual vs Predicted Performance Index')
plt.show()

# %%
x.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced'],
#       dtype='object')

# %%
def makepredict():
    a=float(input("Number of hours studied : "))
    b=float(input("previous Score : "))
    c=float(input("Extracurricular Activities : "))
    d=float(input("Sleep Hours : "))
    e=float(input("Sample Question Papers Practiced : "))
    yp = lr.predict([[a,b,c,d,e]])[0]
    return yp

# %%
makepredict()
# Out:
# np.float64(62.00316835391589)

# %%
mae_instance = abs(ytest[:5] - ypred[:5])
print("MAE for each instance: ", mae_instance)
# Out:
# MAE for each instance:  6252    3.711854
# 4684    2.615513
# 1731    1.903145
# 4742    3.289767
# 4521    2.004570
# Name: Performance Index, dtype: float64

# %%
mse_instance = (ytest[:5] - ypred[:5])**2
print("MSE for each instance: ", mse_instance)
# Out:
# MSE for each instance:  6252    13.777860
# 4684     6.840908
# 1731     3.621960
# 4742    10.822570
# 4521     4.018303
# Name: Performance Index, dtype: float64

# %%
rmse_instance = np.sqrt((ytest[:5] - ypred[:5])**2)
print("RMSE for each instance: ", rmse_instance)
# Out:
# RMSE for each instance:  6252    3.711854
# 4684    2.615513
# 1731    1.903145
# 4742    3.289767
# 4521    2.004570
# Name: Performance Index, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
rmse=np.sqrt(mse)
r2=r2_score(ytest,ypred)
print("Mean Absolute Error : ",mae)
print("Mean Squared Error : ",mse)
print("Root Mean Squared Error : ",rmse)
print("r2_score (Accuracy): ",r2)
# Out:
# Mean Absolute Error :  1.6111213463123044
# Mean Squared Error :  4.082628398521853
# Root Mean Squared Error :  2.0205515085050054
# r2_score (Accuracy):  0.9889832909573145
